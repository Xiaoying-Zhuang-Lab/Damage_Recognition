# %%
google_colab_flag = True # Make it False if do not intend to use Google Colab and want to train in local machine!!

# For training in Google Colab
if(google_colab_flag):
  from google.colab import drive
  drive.mount('/content/drive')
  # !ls
  import sys
  root_path = '/content/drive/MyDrive/Research/' # This is the path to where in google drive the code is stored!
  sys.path.append(root_path)

# For local training
else:
  root_path = ''
# Out:
# Mounted at /content/drive
# drive  sample_data

# %%
import zipfile
with zipfile.ZipFile(root_path + "Dataset.zip","r") as zip_ref:
  zip_ref.extractall(root_path + "")

# %%
from sklearn.preprocessing import label_binarize
from scipy import interp
import matplotlib.pyplot as plt
from itertools import cycle
from sklearn.metrics import roc_curve, auc

import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import StratifiedKFold
from PIL import Image
import random
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Activation, ReLU, add
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Reshape, Concatenate, Lambda
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.compat.v1 import ConfigProto, InteractiveSession
from glob import glob
import warnings
import os
import shutil
from PIL import ImageFile
warnings.simplefilter('error', Image.DecompressionBombWarning)
ImageFile.LOAD_TRUNCATED_IMAGES = True
from PIL import Image
Image.MAX_IMAGE_PIXELS = 1000000000
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
import matplotlib.pyplot as plt

from sklearn import svm
from sklearn.metrics import auc
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import StratifiedKFold

# %%
#root_path = 'C:/Users/USER/Downloads/anhi/'
datasetFolderName = root_path + 'Dataset'
sourceFiles = []
classLabels = ['light', 'moderate', 'no', 'severe']
X = []
Y = []

img_rows, img_cols = 224, 224 # input image dimensions
train_path = datasetFolderName+'/train/'
validation_path = datasetFolderName+'/valid/'
test_path = datasetFolderName+'/test/'

# %%
def transferBetweenFolders(source, dest, splitRate): 
    global sourceFiles
    sourceFiles = os.listdir(source)
    if(len(sourceFiles)!=0):
        transferFileNumbers = int(len(sourceFiles)*splitRate)
        transferIndex = random.sample(range(0, len(sourceFiles)), transferFileNumbers)
        for eachIndex in transferIndex:
            shutil.move(source+str(sourceFiles[eachIndex]), dest+str(sourceFiles[eachIndex]))
    else:
        print("No file moved. Source empty!")
        
def transferAllClassBetweenFolders(source, dest, splitRate):
    for label in classLabels:
        transferBetweenFolders(datasetFolderName+'/'+source+'/'+label+'/', 
                               datasetFolderName+'/'+dest+'/'+label+'/', 
                               splitRate)

def my_metrics(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    f1Score = f1_score(y_true, y_pred, average='weighted') 
    print("Accuracy  : {}".format(accuracy))
    print("Precision : {}".format(precision))
    print("recall : {}".format(recall))
    print("f1Score : {}".format(f1Score))
    cm = confusion_matrix(y_true, y_pred)
    print(cm)
    return accuracy, precision, recall, f1Score

# %%
def prepareNameWithLabels(folderName):
    sourceFiles=os.listdir(datasetFolderName+'/train/'+folderName)
    for val in sourceFiles:
        X.append(val)
        for i in range(len(classLabels)):
            if(folderName==classLabels[i]):
                Y.append(i)

# %%
# Organize file names and class labels in X and Y variables
for i in range(len(classLabels)):
    prepareNameWithLabels(classLabels[i])

# %%
X = np.asarray(X)
Y = np.asarray(Y)

# %%
# Note that, this model structure is a very basic one
epoch = 30
batch_size = 32

# re-size all the images to this
IMAGE_SIZE = [224, 224]

# %%
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.applications.mobilenet import preprocess_input

def getModel():
    mobilenet = MobileNet(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

    # don't train existing weights
    for layer in mobilenet.layers:
      layer.trainable = False
    # our layers - you can add more if you want
    x = Flatten()(mobilenet.output)
    """
    x = Dense(128, activation="relu")(x)
    x = Dropout(0.2)(x)
    """
    prediction = Dense(len(classLabels), activation='softmax')(x)
    # create a model object
    model = Model(inputs=mobilenet.input, outputs=prediction)
    # tell the model what cost and optimization method to use
    model.compile(
      loss='categorical_crossentropy',
      optimizer='sgd',
      metrics=['accuracy']
    )
    return model

# %% [markdown]
# # **Stratified K-Fold Cross validation**

# %%
# ===============Stratified K-Fold======================
skf = StratifiedKFold(n_splits=5, shuffle=True)
skf.get_n_splits(X, Y)
foldNum = 0

for train_index, val_index in skf.split(X, Y):
    # First cut all images from validation to train (if any exists)
    transferAllClassBetweenFolders('valid', 'train', 1.0)
    foldNum += 1
    print("Results for fold",foldNum)
    X_train, X_val = X[train_index], X[val_index]
    Y_train, Y_val = Y[train_index], Y[val_index]
    # Move validation images of this fold from train folder to the validation folder
    for eachIndex in range(len(X_val)):
        classLabel = ''
        for i in range(len(classLabels)):
          if(Y_val[eachIndex]==i):
              classLabel=classLabels[i]
        # Then, copy the validation images to the validation folder
        shutil.move(datasetFolderName+'/train/'+classLabel+'/'+X_val[eachIndex], 
                    datasetFolderName+'/valid/'+classLabel+'/'+X_val[eachIndex])
        
    train_datagen = ImageDataGenerator(rescale=1./255,
                                       shear_range=0.2,
                                       zoom_range=0.2,
                                       horizontal_flip=True)
    validation_datagen = ImageDataGenerator(rescale=1./255)
    test_datagen = ImageDataGenerator(rescale=1./255)
        
    # Start ImageClassification Model
    train_generator = train_datagen.flow_from_directory(
        train_path,
        target_size=(img_rows, img_cols),
        batch_size=batch_size,
        class_mode='categorical',
        subset='training')

    validation_generator = validation_datagen.flow_from_directory(
        validation_path,
        target_size=(img_rows, img_cols),
        batch_size=batch_size,
        class_mode='categorical')   
    
    model=getModel()   
    # fit model
    history=model.fit_generator(train_generator, 
                                validation_data=validation_generator,
                                epochs=epoch)
    
    result = pd.DataFrame(history.history)
    result.to_csv(root_path + 'training_history_fold_{}.csv'.format(foldNum))

    # loss
    fig, axes = plt.subplots(1, 1, figsize=(6, 4))
    plt.plot(history.history['loss'], label='train loss')
    plt.plot(history.history['val_loss'], label='val loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    fig.savefig(root_path + 'loss_fold_{}'.format(foldNum), dpi=3000)

    # accuracy
    fig, axes = plt.subplots(1, 1, figsize=(6, 4))
    plt.plot(history.history['accuracy'], label='train accuracy')
    plt.plot(history.history['val_accuracy'], label='val accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()
    fig.savefig(root_path + 'accuracy_fold_{}'.format(foldNum), dpi=3000)


    print("==============TEST RESULTS============")
    test_generator = test_datagen.flow_from_directory(
            test_path,
            target_size=(img_rows, img_cols),
            batch_size=batch_size,
            class_mode=None,
            shuffle=False) 
    predictions = model.predict(test_generator, verbose=1)
    yPredictions = np.argmax(predictions, axis=1)
    true_classes = test_generator.classes

    testAcc, testPrec, testRecall, testFScore = my_metrics(true_classes, yPredictions)
    model.save(root_path + "model_fold_{}.h5".format(foldNum))

    Y_pred = model.predict(test_generator, verbose=1)
 
    #Confusion matrix
    import itertools
    def plot_confusion_matrix(cm, classes,
                              normalize=False,
                              title='Confusion matrix',
                              cmap=plt.cm.Purples):
        """
        This function prints and plots the confusion matrix.
        Normalization can be applied by setting `normalize=True`.
        """
        if normalize:
            cm = cm.astype('float') / cm.sum(axis=1, keepdims = True)

        plt.figure(figsize=(5, 5))
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
        plt.title(title)
        plt.colorbar()
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes, rotation=45)
        plt.yticks(tick_marks, classes)

        fmt = '.2f' if normalize else 'd'
        thresh = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, format(cm[i, j], fmt),
                    horizontalalignment="center",
                    color="white" if cm[i, j] > thresh else "black")

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

    cm = confusion_matrix(y_true = test_generator.classes, y_pred = np.argmax(Y_pred, axis = -1))
    class_names = ['light', 'moderate', 'no', 'severe']
      
    # Plot non-normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cm, classes=class_names,
                          title='Confusion matrix, without normalization')
    plt.show()
    fig.savefig(root_path + 'confusion_matrix_0_fold_{}'.format(foldNum), dpi=3000) 

    # Plot normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cm, classes=class_names, normalize=True,
                          title='Normalized confusion matrix')
    plt.show()
    fig.savefig(root_path + 'confusion_matrix_1_fold_{}'.format(foldNum), dpi=3000)

    
    #Thao add for ROC curve
    y_true1 = label_binarize(true_classes,classes=[0,1,2,3])    

    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    thresholds = dict()
    n_classes = y_true1.shape[1]
    for k in range(n_classes):
        fpr[k], tpr[k], thresholds[k] = roc_curve(y_true1[:,k], predictions[:,k], drop_intermediate=False)
        roc_auc[k] = auc(fpr[k], tpr[k])
    
    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(y_true1.ravel(), predictions.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
   
    all_fpr = np.unique(np.concatenate([fpr[k] for k in range(n_classes)]))
    
    mean_tpr = np.zeros_like(all_fpr)
    for k in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[k], tpr[k])
    
    # Finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    lw = 2
    fig, axes = plt.subplots(1, 1, figsize=(7, 5))
    plt.plot(fpr["micro"], tpr["micro"],
             label='micro-average ROC curve (area = {0:0.2f})'
                   ''.format(roc_auc["micro"]),
             color='deeppink', linestyle=':', linewidth=4)

    plt.plot(fpr["macro"], tpr["macro"],
             label='macro-average ROC curve (area = {0:0.2f})'
                   ''.format(roc_auc["macro"]),
             color='navy', linestyle=':', linewidth=4)

    colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'red'])
    for k, color in zip(range(n_classes), colors):
        plt.plot(fpr[k], tpr[k], color=color, lw=lw,
                 label='ROC curve of class {0} (area = {1:0.2f})'
                 ''.format(k, roc_auc[k]))

    plt.plot([0, 1], [0, 1], 'k--', lw=lw)
    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Some extension of Receiver operating characteristic to multi-class')
    plt.legend(loc="lower right")
    plt.show()
    fig.savefig(root_path + 'Some extension of Receiver operating characteristic to multi-class_fold_{}'.format(foldNum), dpi=3000)
# Out:
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# Results for fold 1
# Found 1600 images belonging to 4 classes.
# Found 400 images belonging to 4 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# 17235968/17225924 [==============================] - 0s 0us/step
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/30
# 50/50 [==============================] - 37s 448ms/step - loss: 36.8456 - accuracy: 0.4419 - val_loss: 49.6320 - val_accuracy: 0.4475
# Epoch 2/30
# 50/50 [==============================] - 23s 457ms/step - loss: 16.5906 - accuracy: 0.6144 - val_loss: 25.1918 - val_accuracy: 0.5200
# Epoch 3/30
# 50/50 [==============================] - 22s 433ms/step - loss: 9.3235 - accuracy: 0.6938 - val_loss: 21.3745 - val_accuracy: 0.4450
# Epoch 4/30
# 50/50 [==============================] - 23s 459ms/step - loss: 7.3967 - accuracy: 0.7450 - val_loss: 11.4177 - val_accuracy: 0.5975
# Epoch 5/30
# 50/50 [==============================] - 23s 466ms/step - loss: 6.1286 - accuracy: 0.7881 - val_loss: 12.2035 - val_accuracy: 0.5525
# Epoch 6/30
# 50/50 [==============================] - 22s 436ms/step - loss: 4.2527 - accuracy: 0.8037 - val_loss: 29.3576 - val_accuracy: 0.5500
# Epoch 7/30
# 50/50 [==============================] - 22s 440ms/step - loss: 2.9155 - accuracy: 0.8475 - val_loss: 7.9903 - val_accuracy: 0.6475
# Epoch 8/30
# 50/50 [==============================] - 22s 441ms/step - loss: 1.3587 - accuracy: 0.8919 - val_loss: 8.0947 - val_accuracy: 0.6525
# Epoch 9/30
# 50/50 [==============================] - 22s 436ms/step - loss: 1.6209 - accuracy: 0.9119 - val_loss: 10.3978 - val_accuracy: 0.6300
# Epoch 10/30
# 50/50 [==============================] - 22s 431ms/step - loss: 0.7906 - accuracy: 0.9300 - val_loss: 8.2364 - val_accuracy: 0.6375
# Epoch 11/30
# 50/50 [==============================] - 22s 437ms/step - loss: 1.1105 - accuracy: 0.9112 - val_loss: 7.9540 - val_accuracy: 0.6550
# Epoch 12/30
# 50/50 [==============================] - 22s 432ms/step - loss: 0.7168 - accuracy: 0.9388 - val_loss: 7.7946 - val_accuracy: 0.6450
# Epoch 13/30
# 50/50 [==============================] - 22s 443ms/step - loss: 1.1976 - accuracy: 0.9281 - val_loss: 8.5488 - val_accuracy: 0.6475
# Epoch 14/30
# 50/50 [==============================] - 22s 427ms/step - loss: 0.6781 - accuracy: 0.9463 - val_loss: 7.5572 - val_accuracy: 0.6750
# Epoch 15/30
# 50/50 [==============================] - 22s 430ms/step - loss: 0.5738 - accuracy: 0.9463 - val_loss: 7.5499 - val_accuracy: 0.6725
# Epoch 16/30
# 50/50 [==============================] - 23s 455ms/step - loss: 0.3301 - accuracy: 0.9663 - val_loss: 8.6604 - val_accuracy: 0.6550
# Epoch 17/30
# 50/50 [==============================] - 22s 431ms/step - loss: 0.2492 - accuracy: 0.9712 - val_loss: 7.5997 - val_accuracy: 0.6775
# Epoch 18/30
# 50/50 [==============================] - 21s 429ms/step - loss: 0.3075 - accuracy: 0.9706 - val_loss: 7.2595 - val_accuracy: 0.7075
# Epoch 19/30
# 50/50 [==============================] - 22s 449ms/step - loss: 0.3030 - accuracy: 0.9675 - val_loss: 8.2081 - val_accuracy: 0.6800
# Epoch 20/30
# 50/50 [==============================] - 21s 429ms/step - loss: 0.1886 - accuracy: 0.9787 - val_loss: 7.7747 - val_accuracy: 0.6575
# Epoch 21/30
# 50/50 [==============================] - 22s 431ms/step - loss: 0.2329 - accuracy: 0.9737 - val_loss: 7.2635 - val_accuracy: 0.6850
# Epoch 22/30
# 50/50 [==============================] - 23s 451ms/step - loss: 0.2291 - accuracy: 0.9769 - val_loss: 7.7139 - val_accuracy: 0.6975
# Epoch 23/30
# 50/50 [==============================] - 21s 428ms/step - loss: 0.1215 - accuracy: 0.9819 - val_loss: 7.7687 - val_accuracy: 0.6900
# Epoch 24/30
# 50/50 [==============================] - 21s 428ms/step - loss: 0.1126 - accuracy: 0.9869 - val_loss: 8.3024 - val_accuracy: 0.6625
# Epoch 25/30
# 50/50 [==============================] - 22s 450ms/step - loss: 0.1483 - accuracy: 0.9844 - val_loss: 7.6603 - val_accuracy: 0.6900
# Epoch 26/30
# 50/50 [==============================] - 22s 431ms/step - loss: 0.1839 - accuracy: 0.9719 - val_loss: 7.8990 - val_accuracy: 0.6750
# Epoch 27/30
# 50/50 [==============================] - 22s 438ms/step - loss: 0.2084 - accuracy: 0.9781 - val_loss: 7.6877 - val_accuracy: 0.6725
# Epoch 28/30
# 50/50 [==============================] - 22s 430ms/step - loss: 0.0862 - accuracy: 0.9869 - val_loss: 7.7000 - val_accuracy: 0.6525
# Epoch 29/30
# 50/50 [==============================] - 22s 449ms/step - loss: 0.0906 - accuracy: 0.9900 - val_loss: 7.6083 - val_accuracy: 0.6750
# Epoch 30/30
# 50/50 [==============================] - 22s 436ms/step - loss: 0.0636 - accuracy: 0.9906 - val_loss: 7.9450 - val_accuracy: 0.6550
# ==============TEST RESULTS============
# Found 180 images belonging to 4 classes.
# 6/6 [==============================] - 1s 189ms/step
# Accuracy  : 0.8611111111111112
# Precision : 0.8853021978021978
# recall : 0.8611111111111112
# f1Score : 0.8640290426138415
# [[37  7  0  1]
#  [ 0 40  0  5]
#  [ 0  7 35  3]
#  [ 0  2  0 43]]
# 6/6 [==============================] - 1s 117ms/step
# Results for fold 2
# Found 1600 images belonging to 4 classes.
# Found 400 images belonging to 4 classes.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/30
# 50/50 [==============================] - 23s 443ms/step - loss: 37.9283 - accuracy: 0.4181 - val_loss: 24.4291 - val_accuracy: 0.5625
# Epoch 2/30
# 50/50 [==============================] - 22s 438ms/step - loss: 13.4268 - accuracy: 0.6169 - val_loss: 11.5174 - val_accuracy: 0.5850
# Epoch 3/30
# 50/50 [==============================] - 23s 455ms/step - loss: 14.9499 - accuracy: 0.6475 - val_loss: 22.9392 - val_accuracy: 0.5950
# Epoch 4/30
# 50/50 [==============================] - 22s 434ms/step - loss: 7.2105 - accuracy: 0.7487 - val_loss: 11.8914 - val_accuracy: 0.6225
# Epoch 5/30
# 50/50 [==============================] - 22s 432ms/step - loss: 4.0505 - accuracy: 0.7987 - val_loss: 8.7603 - val_accuracy: 0.6650
# Epoch 6/30
# 50/50 [==============================] - 22s 433ms/step - loss: 4.5804 - accuracy: 0.8231 - val_loss: 8.0022 - val_accuracy: 0.6350
# Epoch 7/30
# 50/50 [==============================] - 22s 434ms/step - loss: 4.0133 - accuracy: 0.8263 - val_loss: 15.5329 - val_accuracy: 0.5925
# Epoch 8/30
# 50/50 [==============================] - 23s 461ms/step - loss: 1.7230 - accuracy: 0.8944 - val_loss: 8.0970 - val_accuracy: 0.6750
# Epoch 9/30
# 50/50 [==============================] - 24s 472ms/step - loss: 0.9010 - accuracy: 0.9312 - val_loss: 8.7219 - val_accuracy: 0.6550
# Epoch 10/30
# 50/50 [==============================] - 25s 502ms/step - loss: 0.8511 - accuracy: 0.9331 - val_loss: 8.2234 - val_accuracy: 0.6725
# Epoch 11/30
# 50/50 [==============================] - 21s 429ms/step - loss: 1.5411 - accuracy: 0.9181 - val_loss: 10.6933 - val_accuracy: 0.6325
# Epoch 12/30
# 50/50 [==============================] - 22s 430ms/step - loss: 0.7150 - accuracy: 0.9406 - val_loss: 8.2007 - val_accuracy: 0.6475
# Epoch 13/30
# 50/50 [==============================] - 23s 453ms/step - loss: 0.4651 - accuracy: 0.9588 - val_loss: 8.0881 - val_accuracy: 0.6500
# Epoch 14/30
# 50/50 [==============================] - 22s 431ms/step - loss: 0.4407 - accuracy: 0.9575 - val_loss: 8.1929 - val_accuracy: 0.6850
# Epoch 15/30
# 50/50 [==============================] - 23s 459ms/step - loss: 0.4625 - accuracy: 0.9594 - val_loss: 8.2535 - val_accuracy: 0.6725
# Epoch 16/30
# 50/50 [==============================] - 23s 452ms/step - loss: 0.3290 - accuracy: 0.9644 - val_loss: 7.5141 - val_accuracy: 0.6925
# Epoch 17/30
# 50/50 [==============================] - 22s 438ms/step - loss: 0.3750 - accuracy: 0.9569 - val_loss: 7.7274 - val_accuracy: 0.6700
# Epoch 18/30
# 50/50 [==============================] - 23s 452ms/step - loss: 0.2255 - accuracy: 0.9769 - val_loss: 7.4591 - val_accuracy: 0.7000
# Epoch 19/30
# 50/50 [==============================] - 22s 434ms/step - loss: 0.1879 - accuracy: 0.9819 - val_loss: 7.4444 - val_accuracy: 0.6900
# Epoch 20/30
# 50/50 [==============================] - 22s 440ms/step - loss: 0.1965 - accuracy: 0.9775 - val_loss: 8.3795 - val_accuracy: 0.6675
# Epoch 21/30
# 50/50 [==============================] - 22s 435ms/step - loss: 0.3169 - accuracy: 0.9725 - val_loss: 8.1046 - val_accuracy: 0.6550
# Epoch 22/30
# 50/50 [==============================] - 22s 441ms/step - loss: 0.1478 - accuracy: 0.9825 - val_loss: 7.8345 - val_accuracy: 0.6600
# Epoch 23/30
# 50/50 [==============================] - 22s 435ms/step - loss: 0.1287 - accuracy: 0.9856 - val_loss: 7.3798 - val_accuracy: 0.6975
# Epoch 24/30
# 50/50 [==============================] - 22s 432ms/step - loss: 0.1544 - accuracy: 0.9769 - val_loss: 7.4255 - val_accuracy: 0.6950
# Epoch 25/30
# 50/50 [==============================] - 23s 453ms/step - loss: 0.1384 - accuracy: 0.9844 - val_loss: 7.8402 - val_accuracy: 0.6900
# Epoch 26/30
# 50/50 [==============================] - 22s 431ms/step - loss: 0.1668 - accuracy: 0.9819 - val_loss: 7.8559 - val_accuracy: 0.6975
# Epoch 27/30
# 50/50 [==============================] - 22s 430ms/step - loss: 0.0678 - accuracy: 0.9869 - val_loss: 7.9999 - val_accuracy: 0.6800
# Epoch 28/30
# 50/50 [==============================] - 23s 454ms/step - loss: 0.1351 - accuracy: 0.9819 - val_loss: 7.4162 - val_accuracy: 0.6925
# Epoch 29/30
# 50/50 [==============================] - 21s 429ms/step - loss: 0.1082 - accuracy: 0.9831 - val_loss: 7.9855 - val_accuracy: 0.6825
# Epoch 30/30
# 50/50 [==============================] - 23s 453ms/step - loss: 0.1563 - accuracy: 0.9831 - val_loss: 7.5362 - val_accuracy: 0.6825
# ==============TEST RESULTS============
# Found 180 images belonging to 4 classes.
# 6/6 [==============================] - 1s 118ms/step
# Accuracy  : 0.9444444444444444
# Precision : 0.9452638082957231
# recall : 0.9444444444444444
# f1Score : 0.9446819193399555
# [[43  2  0  0]
#  [ 1 40  0  4]
#  [ 0  1 44  0]
#  [ 0  2  0 43]]
# 6/6 [==============================] - 1s 117ms/step
# Results for fold 3
# Found 1600 images belonging to 4 classes.
# Found 400 images belonging to 4 classes.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/30
# 50/50 [==============================] - 25s 472ms/step - loss: 33.7175 - accuracy: 0.4419 - val_loss: 21.5027 - val_accuracy: 0.4600
# Epoch 2/30
# 50/50 [==============================] - 22s 434ms/step - loss: 17.2390 - accuracy: 0.5856 - val_loss: 27.5207 - val_accuracy: 0.5900
# Epoch 3/30
# 50/50 [==============================] - 22s 436ms/step - loss: 9.6947 - accuracy: 0.6856 - val_loss: 20.2285 - val_accuracy: 0.4725
# Epoch 4/30
# 50/50 [==============================] - 23s 457ms/step - loss: 7.8865 - accuracy: 0.7237 - val_loss: 20.6460 - val_accuracy: 0.6300
# Epoch 5/30
# 50/50 [==============================] - 22s 432ms/step - loss: 5.7985 - accuracy: 0.7656 - val_loss: 12.0117 - val_accuracy: 0.5750
# Epoch 6/30
# 50/50 [==============================] - 22s 430ms/step - loss: 3.4229 - accuracy: 0.8269 - val_loss: 9.0029 - val_accuracy: 0.6275
# Epoch 7/30
# 50/50 [==============================] - 22s 435ms/step - loss: 1.8154 - accuracy: 0.8863 - val_loss: 8.4710 - val_accuracy: 0.6200
# Epoch 8/30
# 50/50 [==============================] - 22s 433ms/step - loss: 1.3329 - accuracy: 0.9069 - val_loss: 10.5687 - val_accuracy: 0.5950
# Epoch 9/30
# 50/50 [==============================] - 23s 450ms/step - loss: 1.0447 - accuracy: 0.9212 - val_loss: 8.1413 - val_accuracy: 0.6675
# Epoch 10/30
# 50/50 [==============================] - 22s 434ms/step - loss: 0.7335 - accuracy: 0.9319 - val_loss: 9.8875 - val_accuracy: 0.5775
# Epoch 11/30
# 50/50 [==============================] - 22s 432ms/step - loss: 0.8451 - accuracy: 0.9350 - val_loss: 10.0275 - val_accuracy: 0.6025
# Epoch 12/30
# 50/50 [==============================] - 22s 434ms/step - loss: 0.9877 - accuracy: 0.9262 - val_loss: 8.6652 - val_accuracy: 0.6225
# Epoch 13/30
# 50/50 [==============================] - 24s 475ms/step - loss: 0.4656 - accuracy: 0.9506 - val_loss: 8.5009 - val_accuracy: 0.6650
# Epoch 14/30
# 50/50 [==============================] - 22s 436ms/step - loss: 0.4379 - accuracy: 0.9538 - val_loss: 7.8489 - val_accuracy: 0.6300
# Epoch 15/30
# 50/50 [==============================] - 21s 430ms/step - loss: 0.3028 - accuracy: 0.9669 - val_loss: 7.5299 - val_accuracy: 0.6400
# Epoch 16/30
# 50/50 [==============================] - 23s 452ms/step - loss: 0.3298 - accuracy: 0.9631 - val_loss: 7.9398 - val_accuracy: 0.6300
# Epoch 17/30
# 50/50 [==============================] - 22s 432ms/step - loss: 0.2534 - accuracy: 0.9706 - val_loss: 8.4898 - val_accuracy: 0.6075
# Epoch 18/30
# 50/50 [==============================] - 23s 460ms/step - loss: 0.1440 - accuracy: 0.9787 - val_loss: 8.2593 - val_accuracy: 0.6325
# Epoch 19/30
# 50/50 [==============================] - 23s 462ms/step - loss: 0.2320 - accuracy: 0.9775 - val_loss: 7.8596 - val_accuracy: 0.6500
# Epoch 20/30
# 50/50 [==============================] - 22s 434ms/step - loss: 0.1587 - accuracy: 0.9775 - val_loss: 9.0915 - val_accuracy: 0.5950
# Epoch 21/30
# 50/50 [==============================] - 22s 434ms/step - loss: 0.2284 - accuracy: 0.9806 - val_loss: 8.1909 - val_accuracy: 0.6425
# Epoch 22/30
# 50/50 [==============================] - 23s 451ms/step - loss: 0.1865 - accuracy: 0.9769 - val_loss: 7.9699 - val_accuracy: 0.6425
# Epoch 23/30
# 50/50 [==============================] - 22s 433ms/step - loss: 0.1055 - accuracy: 0.9819 - val_loss: 8.2522 - val_accuracy: 0.6375
# Epoch 24/30
# 50/50 [==============================] - 22s 433ms/step - loss: 0.0766 - accuracy: 0.9894 - val_loss: 7.8554 - val_accuracy: 0.6500
# Epoch 25/30
# 50/50 [==============================] - 22s 449ms/step - loss: 0.1483 - accuracy: 0.9794 - val_loss: 8.0059 - val_accuracy: 0.6500
# Epoch 26/30
# 50/50 [==============================] - 22s 431ms/step - loss: 0.1945 - accuracy: 0.9750 - val_loss: 9.0901 - val_accuracy: 0.6300
# Epoch 27/30
# 50/50 [==============================] - 22s 450ms/step - loss: 0.1224 - accuracy: 0.9837 - val_loss: 8.5603 - val_accuracy: 0.6600
# Epoch 28/30
# 50/50 [==============================] - 22s 432ms/step - loss: 0.0974 - accuracy: 0.9862 - val_loss: 8.4377 - val_accuracy: 0.6425
# Epoch 29/30
# 50/50 [==============================] - 21s 429ms/step - loss: 0.1669 - accuracy: 0.9806 - val_loss: 7.9040 - val_accuracy: 0.6175
# Epoch 30/30
# 50/50 [==============================] - 23s 453ms/step - loss: 0.1927 - accuracy: 0.9812 - val_loss: 8.4901 - val_accuracy: 0.6425
# ==============TEST RESULTS============
# Found 180 images belonging to 4 classes.
# 6/6 [==============================] - 1s 122ms/step
# Accuracy  : 0.9333333333333333
# Precision : 0.9355113636363636
# recall : 0.9333333333333333
# f1Score : 0.9331087563695285
# [[39  4  1  1]
#  [ 1 42  1  1]
#  [ 0  2 42  1]
#  [ 0  0  0 45]]
# 6/6 [==============================] - 1s 118ms/step
# Results for fold 4
# Found 1600 images belonging to 4 classes.
# Found 400 images belonging to 4 classes.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/30
# 50/50 [==============================] - 26s 485ms/step - loss: 32.6206 - accuracy: 0.4450 - val_loss: 26.2102 - val_accuracy: 0.5225
# Epoch 2/30
# 50/50 [==============================] - 22s 437ms/step - loss: 19.0464 - accuracy: 0.5756 - val_loss: 18.9937 - val_accuracy: 0.5775
# Epoch 3/30
# 50/50 [==============================] - 23s 464ms/step - loss: 11.1198 - accuracy: 0.6594 - val_loss: 16.5390 - val_accuracy: 0.5575
# Epoch 4/30
# 50/50 [==============================] - 22s 440ms/step - loss: 8.9739 - accuracy: 0.7275 - val_loss: 10.9210 - val_accuracy: 0.6350
# Epoch 5/30
# 50/50 [==============================] - 22s 435ms/step - loss: 5.5196 - accuracy: 0.7750 - val_loss: 20.5618 - val_accuracy: 0.5150
# Epoch 6/30
# 50/50 [==============================] - 22s 437ms/step - loss: 2.4450 - accuracy: 0.8600 - val_loss: 10.9856 - val_accuracy: 0.6525
# Epoch 7/30
# 50/50 [==============================] - 23s 451ms/step - loss: 2.0215 - accuracy: 0.8763 - val_loss: 13.4073 - val_accuracy: 0.5575
# Epoch 8/30
# 50/50 [==============================] - 22s 438ms/step - loss: 1.2952 - accuracy: 0.9038 - val_loss: 11.0579 - val_accuracy: 0.6075
# Epoch 9/30
# 50/50 [==============================] - 22s 434ms/step - loss: 0.9988 - accuracy: 0.9225 - val_loss: 23.8182 - val_accuracy: 0.4650
# Epoch 10/30
# 50/50 [==============================] - 22s 433ms/step - loss: 1.4570 - accuracy: 0.9106 - val_loss: 9.0574 - val_accuracy: 0.6650
# Epoch 11/30
# 50/50 [==============================] - 22s 435ms/step - loss: 0.5921 - accuracy: 0.9413 - val_loss: 8.0224 - val_accuracy: 0.6775
# Epoch 12/30
# 50/50 [==============================] - 22s 437ms/step - loss: 0.3949 - accuracy: 0.9613 - val_loss: 8.0007 - val_accuracy: 0.6700
# Epoch 13/30
# 50/50 [==============================] - 22s 441ms/step - loss: 0.5422 - accuracy: 0.9481 - val_loss: 8.2489 - val_accuracy: 0.6600
# Epoch 14/30
# 50/50 [==============================] - 22s 435ms/step - loss: 0.5365 - accuracy: 0.9525 - val_loss: 7.9306 - val_accuracy: 0.6625
# Epoch 15/30
# 50/50 [==============================] - 22s 435ms/step - loss: 0.3670 - accuracy: 0.9656 - val_loss: 7.9397 - val_accuracy: 0.6850
# Epoch 16/30
# 50/50 [==============================] - 23s 453ms/step - loss: 0.2539 - accuracy: 0.9719 - val_loss: 9.6602 - val_accuracy: 0.6325
# Epoch 17/30
# 50/50 [==============================] - 22s 437ms/step - loss: 0.1504 - accuracy: 0.9787 - val_loss: 8.6101 - val_accuracy: 0.6625
# Epoch 18/30
# 50/50 [==============================] - 22s 437ms/step - loss: 0.2659 - accuracy: 0.9719 - val_loss: 7.6600 - val_accuracy: 0.6800
# Epoch 19/30
# 50/50 [==============================] - 22s 435ms/step - loss: 0.2505 - accuracy: 0.9750 - val_loss: 7.7327 - val_accuracy: 0.6650
# Epoch 20/30
# 50/50 [==============================] - 22s 435ms/step - loss: 0.2313 - accuracy: 0.9756 - val_loss: 8.4247 - val_accuracy: 0.6775
# Epoch 21/30
# 50/50 [==============================] - 22s 445ms/step - loss: 0.2642 - accuracy: 0.9750 - val_loss: 8.4090 - val_accuracy: 0.6750
# Epoch 22/30
# 50/50 [==============================] - 22s 440ms/step - loss: 0.1372 - accuracy: 0.9775 - val_loss: 8.5915 - val_accuracy: 0.6625
# Epoch 23/30
# 50/50 [==============================] - 22s 434ms/step - loss: 0.1752 - accuracy: 0.9806 - val_loss: 9.9615 - val_accuracy: 0.6275
# Epoch 24/30
# 50/50 [==============================] - 23s 458ms/step - loss: 0.1285 - accuracy: 0.9781 - val_loss: 9.1105 - val_accuracy: 0.6375
# Epoch 25/30
# 50/50 [==============================] - 22s 434ms/step - loss: 0.2447 - accuracy: 0.9719 - val_loss: 8.5902 - val_accuracy: 0.6525
# Epoch 26/30
# 50/50 [==============================] - 23s 455ms/step - loss: 0.1130 - accuracy: 0.9869 - val_loss: 8.2837 - val_accuracy: 0.6775
# Epoch 27/30
# 50/50 [==============================] - 22s 435ms/step - loss: 0.1301 - accuracy: 0.9875 - val_loss: 8.7678 - val_accuracy: 0.6625
# Epoch 28/30
# 50/50 [==============================] - 22s 434ms/step - loss: 0.1298 - accuracy: 0.9806 - val_loss: 8.0477 - val_accuracy: 0.6675
# Epoch 29/30
# 50/50 [==============================] - 23s 458ms/step - loss: 0.1042 - accuracy: 0.9875 - val_loss: 7.9920 - val_accuracy: 0.6750
# Epoch 30/30
# 50/50 [==============================] - 22s 439ms/step - loss: 0.1051 - accuracy: 0.9862 - val_loss: 8.0960 - val_accuracy: 0.6800
# ==============TEST RESULTS============
# Found 180 images belonging to 4 classes.
# 6/6 [==============================] - 1s 129ms/step
# Accuracy  : 0.9277777777777778
# Precision : 0.9297328336557059
# recall : 0.9277777777777778
# f1Score : 0.9278527649743407
# [[40  4  0  1]
#  [ 3 41  0  1]
#  [ 1  2 41  1]
#  [ 0  0  0 45]]
# 6/6 [==============================] - 1s 120ms/step
# Results for fold 5
# Found 1600 images belonging to 4 classes.
# Found 400 images belonging to 4 classes.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/30
# 50/50 [==============================] - 25s 473ms/step - loss: 36.2803 - accuracy: 0.4306 - val_loss: 10.6918 - val_accuracy: 0.5900
# Epoch 2/30
# 50/50 [==============================] - 22s 448ms/step - loss: 14.7591 - accuracy: 0.6094 - val_loss: 9.8733 - val_accuracy: 0.6200
# Epoch 3/30
# 50/50 [==============================] - 23s 457ms/step - loss: 9.8012 - accuracy: 0.6844 - val_loss: 9.9446 - val_accuracy: 0.6100
# Epoch 4/30
# 50/50 [==============================] - 22s 439ms/step - loss: 5.8423 - accuracy: 0.7581 - val_loss: 11.2340 - val_accuracy: 0.6450
# Epoch 5/30
# 50/50 [==============================] - 23s 458ms/step - loss: 6.4866 - accuracy: 0.7544 - val_loss: 9.4842 - val_accuracy: 0.6300
# Epoch 6/30
# 50/50 [==============================] - 22s 434ms/step - loss: 3.3066 - accuracy: 0.8394 - val_loss: 11.3968 - val_accuracy: 0.6425
# Epoch 7/30
# 50/50 [==============================] - 22s 439ms/step - loss: 3.1710 - accuracy: 0.8537 - val_loss: 14.8462 - val_accuracy: 0.6425
# Epoch 8/30
# 50/50 [==============================] - 22s 435ms/step - loss: 2.1529 - accuracy: 0.8706 - val_loss: 9.9438 - val_accuracy: 0.6600
# Epoch 9/30
# 50/50 [==============================] - 22s 432ms/step - loss: 0.9414 - accuracy: 0.9269 - val_loss: 8.7603 - val_accuracy: 0.6525
# Epoch 10/30
# 50/50 [==============================] - 22s 436ms/step - loss: 0.7920 - accuracy: 0.9369 - val_loss: 8.8892 - val_accuracy: 0.6700
# Epoch 11/30
# 50/50 [==============================] - 22s 434ms/step - loss: 0.6684 - accuracy: 0.9481 - val_loss: 9.4489 - val_accuracy: 0.6650
# Epoch 12/30
# 50/50 [==============================] - 22s 437ms/step - loss: 0.6256 - accuracy: 0.9413 - val_loss: 9.0305 - val_accuracy: 0.6625
# Epoch 13/30
# 50/50 [==============================] - 22s 432ms/step - loss: 0.6967 - accuracy: 0.9419 - val_loss: 8.8570 - val_accuracy: 0.6300
# Epoch 14/30
# 50/50 [==============================] - 22s 434ms/step - loss: 0.4148 - accuracy: 0.9569 - val_loss: 10.8321 - val_accuracy: 0.6025
# Epoch 15/30
# 50/50 [==============================] - 22s 442ms/step - loss: 0.5847 - accuracy: 0.9506 - val_loss: 8.8098 - val_accuracy: 0.6600
# Epoch 16/30
# 50/50 [==============================] - 22s 436ms/step - loss: 0.2397 - accuracy: 0.9756 - val_loss: 8.4226 - val_accuracy: 0.6700
# Epoch 17/30
# 50/50 [==============================] - 22s 437ms/step - loss: 0.3674 - accuracy: 0.9675 - val_loss: 8.5084 - val_accuracy: 0.6425
# Epoch 18/30
# 50/50 [==============================] - 23s 461ms/step - loss: 0.5980 - accuracy: 0.9625 - val_loss: 8.2977 - val_accuracy: 0.6725
# Epoch 19/30
# 50/50 [==============================] - 22s 435ms/step - loss: 0.2598 - accuracy: 0.9712 - val_loss: 8.9980 - val_accuracy: 0.6675
# Epoch 20/30
# 50/50 [==============================] - 22s 435ms/step - loss: 0.2341 - accuracy: 0.9731 - val_loss: 8.5395 - val_accuracy: 0.6625
# Epoch 21/30
# 50/50 [==============================] - 22s 437ms/step - loss: 0.1304 - accuracy: 0.9837 - val_loss: 8.3466 - val_accuracy: 0.6600
# Epoch 22/30
# 50/50 [==============================] - 22s 436ms/step - loss: 0.1061 - accuracy: 0.9844 - val_loss: 8.6728 - val_accuracy: 0.6550
# Epoch 23/30
# 50/50 [==============================] - 22s 432ms/step - loss: 0.1861 - accuracy: 0.9825 - val_loss: 8.2206 - val_accuracy: 0.6700
# Epoch 24/30
# 50/50 [==============================] - 22s 434ms/step - loss: 0.2139 - accuracy: 0.9744 - val_loss: 7.7192 - val_accuracy: 0.6625
# Epoch 25/30
# 50/50 [==============================] - 22s 434ms/step - loss: 0.1634 - accuracy: 0.9844 - val_loss: 8.6219 - val_accuracy: 0.6625
# Epoch 26/30
# 50/50 [==============================] - 23s 455ms/step - loss: 0.1372 - accuracy: 0.9844 - val_loss: 7.9403 - val_accuracy: 0.6625
# Epoch 27/30
# 50/50 [==============================] - 22s 433ms/step - loss: 0.2047 - accuracy: 0.9744 - val_loss: 8.2540 - val_accuracy: 0.6725
# Epoch 28/30
# 50/50 [==============================] - 22s 435ms/step - loss: 0.1800 - accuracy: 0.9794 - val_loss: 9.1063 - val_accuracy: 0.6450
# Epoch 29/30
# 50/50 [==============================] - 22s 438ms/step - loss: 0.1505 - accuracy: 0.9787 - val_loss: 7.9235 - val_accuracy: 0.6550
# Epoch 30/30
# 50/50 [==============================] - 22s 434ms/step - loss: 0.1848 - accuracy: 0.9794 - val_loss: 8.0070 - val_accuracy: 0.6825
# ==============TEST RESULTS============
# Found 180 images belonging to 4 classes.
# 6/6 [==============================] - 1s 126ms/step
# Accuracy  : 0.8777777777777778
# Precision : 0.8831303017158282
# recall : 0.8777777777777778
# f1Score : 0.8771714266674163
# [[37  7  0  1]
#  [ 3 39  1  2]
#  [ 2  2 37  4]
#  [ 0  0  0 45]]
# 6/6 [==============================] - 1s 119ms/step

# %% [markdown]
# https://stackoverflow.com/questions/70278059/plotting-the-roc-curve-for-a-multiclass-problem
